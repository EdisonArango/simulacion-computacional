# %%
def congruencial(a, b, m, x0, n):
    randoms = []
    for i in range(n):
        xn = float((a * x0 + b) % m)
        x0 = xn
        random = float(xn/m)
        print random
        randoms.append(random)
    return randoms

a = int(raw_input("a: "))
b = int(raw_input("b: "))
m = int(raw_input("m: "))
x0 = int(raw_input("x0: "))
n = int(raw_input("Amount of random numbers to generate: "))
print "Generated numbers:", congruencial(a,b,m,x0,n)
# Out:
# a: 3
# b: 7
# m: 29
# x0: 3
# Amount of random numbers to generate: 50
# Generated numbers: 0.551724137931
# 0.896551724138
# 0.931034482759
# 0.0344827586207
# 0.344827586207
# 0.275862068966
# 0.0689655172414
# 0.448275862069
# 0.586206896552
# 0.0
# 0.241379310345
# 0.965517241379
# 0.137931034483
# 0.655172413793
# 0.206896551724
# 0.862068965517
# 0.827586206897
# 0.724137931034
# 0.413793103448
# 0.48275862069
# 0.689655172414
# 0.310344827586
# 0.172413793103
# 0.758620689655
# 0.51724137931
# 0.793103448276
# 0.620689655172
# 0.103448275862
# 0.551724137931
# 0.896551724138
# 0.931034482759
# 0.0344827586207
# 0.344827586207
# 0.275862068966
# 0.0689655172414
# 0.448275862069
# 0.586206896552
# 0.0
# 0.241379310345
# 0.965517241379
# 0.137931034483
# 0.655172413793
# 0.206896551724
# 0.862068965517
# 0.827586206897
# 0.724137931034
# 0.413793103448
# 0.48275862069
# 0.689655172414
# 0.310344827586
# [0.5517241379310345, 0.896551724137931, 0.9310344827586207, 0.034482758620689655, 0.3448275862068966, 0.27586206896551724, 0.06896551724137931, 0.4482758620689655, 0.5862068965517241, 0.0, 0.2413793103448276, 0.9655172413793104, 0.13793103448275862, 0.6551724137931034, 0.20689655172413793, 0.8620689655172413, 0.8275862068965517, 0.7241379310344828, 0.41379310344827586, 0.4827586206896552, 0.6896551724137931, 0.3103448275862069, 0.1724137931034483, 0.7586206896551724, 0.5172413793103449, 0.7931034482758621, 0.6206896551724138, 0.10344827586206896, 0.5517241379310345, 0.896551724137931, 0.9310344827586207, 0.034482758620689655, 0.3448275862068966, 0.27586206896551724, 0.06896551724137931, 0.4482758620689655, 0.5862068965517241, 0.0, 0.2413793103448276, 0.9655172413793104, 0.13793103448275862, 0.6551724137931034, 0.20689655172413793, 0.8620689655172413, 0.8275862068965517, 0.7241379310344828, 0.41379310344827586, 0.4827586206896552, 0.6896551724137931, 0.3103448275862069]
