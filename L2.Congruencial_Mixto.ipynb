# %%
def congruencial(a, b, m, x0, n):
    randoms = []
    for i in range(n):
        xn = float((a * x0 + b) % m)
        x0 = xn
        random = float(xn/m)
        print random
        randoms.append(random)
    return randoms

a = int(raw_input("a: "))
b = int(raw_input("b: "))
m = int(raw_input("m: "))
x0 = int(raw_input("x0: "))
n = int(raw_input("Amount of random numbers to generate: "))
print "Generated numbers:", congruencial(a,b,m,x0,n)
# Out:
# a: 13
# b: 7
# m: 171
# x0: 25
# Amount of random numbers to generate: 100
# Generated numbers: 0.941520467836
# 0.280701754386
# 0.690058479532
# 0.0116959064327
# 0.19298245614
# 0.549707602339
# 0.187134502924
# 0.473684210526
# 0.198830409357
# 0.625730994152
# 0.175438596491
# 0.321637426901
# 0.222222222222
# 0.929824561404
# 0.12865497076
# 0.713450292398
# 0.315789473684
# 0.146198830409
# 0.941520467836
# 0.280701754386
# 0.690058479532
# 0.0116959064327
# 0.19298245614
# 0.549707602339
# 0.187134502924
# 0.473684210526
# 0.198830409357
# 0.625730994152
# 0.175438596491
# 0.321637426901
# 0.222222222222
# 0.929824561404
# 0.12865497076
# 0.713450292398
# 0.315789473684
# 0.146198830409
# 0.941520467836
# 0.280701754386
# 0.690058479532
# 0.0116959064327
# 0.19298245614
# 0.549707602339
# 0.187134502924
# 0.473684210526
# 0.198830409357
# 0.625730994152
# 0.175438596491
# 0.321637426901
# 0.222222222222
# 0.929824561404
# 0.12865497076
# 0.713450292398
# 0.315789473684
# ...
